# %%
import tweepy
import configparser
import pandas as pd

# %%
config = configparser.ConfigParser()
config.read('config.ini')

api_key = config['twitter']['api_key']
api_key_secret = config['twitter']['api_key_secret']

acces_token = config['twitter']['acces_token']
acces_token_secret = config['twitter']['acces_token_secret']

# %%
# authentication
auth = tweepy.OAuth1UserHandler(api_key, api_key_secret)
auth.set_access_token(acces_token, acces_token_secret)

api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()

column = ['Time', 'User', 'Tweet']
data = []

for tweet in public_tweets:
    data.append([tweet.created_at, tweet.user.screen_name, tweet.text])

df = pd.DataFrame(data, columns=column)
df

df.to_csv('tweet.csv')
# Out:
#                         Time            User  \
# 0  2022-11-10 12:16:55+00:00       worksfess
# 1  2022-11-10 12:16:47+00:00       worksfess
# 2  2022-11-10 12:16:33+00:00       worksfess
# 3  2022-11-10 12:16:29+00:00       worksfess
# 4  2022-11-10 12:16:28+00:00       worksfess
# 5  2022-11-10 12:16:23+00:00  darktracer_int
# 6  2022-11-10 12:16:06+00:00       worksfess
# 7  2022-11-10 12:15:44+00:00       worksfess
# 8  2022-11-10 12:15:43+00:00       worksfess
# 9  2022-11-10 12:14:42+00:00       worksfess
# 10 2022-11-10 12:13:01+00:00       worksfess
# 11 2022-11-10 12:12:52+00:00       worksfess
# 12 2022-11-10 12:11:11+00:00        moritai4
# 13 2022-11-10 12:10:27+00:00       karirfess
#
#                                                 Tweet
# 0   work! kalo kalian disuruh sebutkan 3 kebaikan ...
# 1   work! gmn kata2nya pls, makasih sarannya kaka ...
# 2   Work! Numpang curhat guys, aku lagi wfo, udah ...
# 3   🚀 Human Resources: \n(https://t.co/JoD4gxhYuH)...
# 4   Cus daftar!\n\n🚀 Digital Marketing: \n(https:/...
# 5   RT @ITUARCC: 💠Session:\nIt’s not just a matter...
# 6   [ad] \n\nIkut Kelas Harisenin Skill Camp bisa ...
# 7     link pendaftarannya👇\n(https://t.co/vIjprFfHHj)
# 8   [ad]\n\nLulus Kuliah Bisa Langsung Kerja di Ba...
# 9   Wrk! Halo, mau minta opini kalian dong! Menuru...
# 10  RT @youurSpring: ✨ Totebag Muat Banyak ✨\n~\n🌷...
# 11  RT @eskrimrasalemon: ✨✨ Footwear Wanita ✨✨\n~\...
# 12  RT @azukiosamitu: モリタイシさん版どんぎつねちゃん（西だし派のあたし）\n...
# 13  Temen-temen tolong spill cara nego naik gaji d...
